# %%
import pandas as pd

df = pd.read_excel("Phloem_composition.xls",sheet_name="ProcessedWilkinsonDouglas")

# %%
df.set_index("Metabolite",inplace=True)

# %%
df
# Out:
#                      Arabidopsis thaliana Chenopodium hybridum  \
# Metabolite
# sSUCROSE_b                          68.75              61.5385
# L_ALPHA_ALANINE_c                 3.03125              2.46154
# ARG_c                                 0.5             0.346154
# ASN_c                             3.15625             0.730769
# L_ASPARTATE_c                     2.96875              3.03846
# GLT_c                              3.5625              6.73077
# GLN_c                              10.375              16.3077
# GLY_c                             0.21875             0.769231
# SER_c                             2.40625              1.53846
# TYR_c                              0.1875             0.615385
# HIS_c                               0.125             0.346154
# ILE_c                               0.375             0.615385
# LEU_c                               0.375             0.653846
# LYS_c                              0.5625             0.769231
# MET_c                             0.21875             0.423077
# PHE_c                             0.34375             0.461538
# THR_c                                1.75             0.423077
# TRP_c                             0.28125              1.19231
# VAL_c                                0.75              1.03846
# NaN                                   NaN                  NaN
# NaN                                   NaN                  NaN
# NaN                                   NaN                  NaN
# NaN                                   NaN                  NaN
# NaN                                 Mol %                  NaN
# Plant species                      Sugars                  ala
# Arabidopsis thaliana                68.75                 3.03
# Chenopodium hybridum                61.54                 2.46
# Plantago lanceolata                 87.01                 1.22
# Rumex acetosella                       50                  2.6
# Trifolium repens                    83.87                 1.21
# Viola arvensis                      76.74                 1.26
# Rumex acetosa                       88.76                 0.56
# Rumex obtusifolius                  79.59                 0.88
# Arctium minus                       56.52                 4.22
# Chenopodium album                   78.26                 1.11
# Cirsium arvense                     54.55                 4.59
# Lamium purpureum                     9.09                 5.73
# Papaver dubium                      28.57                 4.36
# Solanum nigrum                         75                 2.33
# Tropaeolum majus                    89.69                 0.77
# Vicia faba                          52.38                 1.43
#
#                      Plantago lanceolata Rumex acetosella Trifolium repens  \
# Metabolite
# sSUCROSE_b                        87.013               50           83.871
# L_ALPHA_ALANINE_c                1.22078              2.6          1.20968
# ARG_c                            1.06494              0.4         0.112903
# ASN_c                           0.337662             2.15          7.33871
# L_ASPARTATE_c                          1             4.75          1.33871
# GLT_c                             2.7013             9.25          1.82258
# GLN_c                            3.50649            15.45         0.370968
# GLY_c                           0.155844             1.45         0.322581
# SER_c                           0.987013                7          1.64516
# TYR_c                           0.142857              0.9         0.177419
# HIS_c                           0.038961              0.3        0.0645161
# ILE_c                           0.168831             0.55         0.129032
# LEU_c                           0.207792             0.75         0.177419
# LYS_c                           0.246753             0.65         0.209677
# MET_c                           0.103896             0.35        0.0645161
# PHE_c                            0.12987              0.4         0.112903
# THR_c                           0.441558              1.3         0.354839
# TRP_c                           0.103896              0.6         0.145161
# VAL_c                           0.428571              1.1         0.290323
# NaN                                  NaN              NaN              NaN
# NaN                                  NaN              NaN              NaN
# NaN                                  NaN              NaN              NaN
# NaN                                  NaN              NaN              NaN
# NaN                                  NaN              NaN              NaN
# Plant species                        arg              asn              asp
# Arabidopsis thaliana                 0.5             3.16             2.97
# Chenopodium hybridum                0.35             0.73             3.04
# Plantago lanceolata                 1.06             0.34                1
# Rumex acetosella                     0.4             2.15             4.75
# Trifolium repens                    0.11             7.34             1.34
# Viola arvensis                      0.28             0.81             2.58
# Rumex acetosa                       0.09             0.17             0.72
# Rumex obtusifolius                  0.31             0.33              2.2
# Arctium minus                       0.57            17.09             2.17
# Chenopodium album                   0.26             0.61             1.67
# Cirsium arvense                     0.45            14.64             1.77
# Lamium purpureum                    0.64             2.55             1.91
# Papaver dubium                      0.29             2.79             16.5
# Solanum nigrum                      0.35             1.35             1.65
# Tropaeolum majus                     0.1              4.3             0.94
# Vicia faba                          0.29            32.71             1.62
#
#                      Viola arvensis Rumex acetosa Rumex obtusifolius  \
# Metabolite
# sSUCROSE_b                  76.7442        88.764            79.5918
# L_ALPHA_ALANINE_c           1.25581      0.561798           0.877551
# ARG_c                       0.27907     0.0898876           0.306122
# ASN_c                      0.813953      0.168539           0.326531
# L_ASPARTATE_c                2.5814      0.719101            2.20408
# GLT_c                       2.72093       2.44944            4.38776
# GLN_c                       10.7907       5.01124            7.36735
# GLY_c                       0.27907      0.123596           0.183673
# SER_c                       2.16279      0.707865            1.59184
# TYR_c                      0.232558      0.269663           0.244898
# HIS_c                     0.0697674     0.0337079           0.102041
# ILE_c                      0.209302     0.0674157           0.204082
# LEU_c                      0.255814     0.0898876           0.306122
# LYS_c                      0.302326     0.0898876           0.265306
# MET_c                     0.0930233     0.0449438           0.204082
# PHE_c                      0.162791     0.0898876           0.265306
# THR_c                      0.395349      0.280899           0.857143
# TRP_c                      0.139535      0.393258           0.265306
# VAL_c                      0.465116      0.157303           0.469388
# NaN                             NaN           NaN                NaN
# NaN                             NaN           NaN                NaN
# NaN                             NaN           NaN                NaN
# NaN                             NaN           NaN                NaN
# NaN                             NaN           NaN                NaN
# Plant species                   glu           gln                gly
# Arabidopsis thaliana           3.56         10.38               0.22
# Chenopodium hybridum           6.73         16.31               0.77
# Plantago lanceolata             2.7          3.51               0.16
# Rumex acetosella               9.25         15.45               1.45
# Trifolium repens               1.82          0.37               0.32
# Viola arvensis                 2.72         10.79               0.28
# Rumex acetosa                  2.45          5.01               0.12
# Rumex obtusifolius             4.39          7.37               0.18
# Arctium minus                  6.52          3.96               0.57
# Chenopodium album              4.67             7               0.43
# Cirsium arvense                5.36          8.55               1.09
# Lamium purpureum               7.36         55.91               4.91
# Papaver dubium                    8         23.86               0.57
# Solanum nigrum                  3.1           8.2               0.68
# Tropaeolum majus               1.15           0.4               0.12
# Vicia faba                     1.76          3.19               0.38
#
#                      Arctium minus Chenopodium album Cirsium arvense  \
# Metabolite
# sSUCROSE_b                 56.5217           78.2609         54.5455
# L_ALPHA_ALANINE_c          4.21739            1.1087         4.59091
# ARG_c                     0.565217           0.26087        0.454545
# ASN_c                       17.087          0.608696         14.6364
# L_ASPARTATE_c              2.17391           1.67391         1.77273
# GLT_c                      6.52174           4.67391         5.36364
# GLN_c                      3.95652                 7         8.54545
# GLY_c                     0.565217          0.434783         1.09091
# SER_c                      3.08696           1.23913         3.72727
# TYR_c                     0.608696          0.326087        0.409091
# HIS_c                     0.304348          0.108696        0.272727
# ILE_c                     0.391304          0.521739        0.454545
# LEU_c                     0.565217          0.652174        0.545455
# LYS_c                     0.608696          0.543478             0.5
# MET_c                      0.26087           0.26087        0.136364
# PHE_c                     0.826087          0.195652        0.590909
# THR_c                     0.782609          0.717391               1
# TRP_c                     0.173913          0.608696        0.318182
# VAL_c                     0.869565          0.673913               1
# NaN                            NaN               NaN             NaN
# NaN                            NaN               NaN             NaN
# NaN                            NaN               NaN             NaN
# NaN                            NaN               NaN             NaN
# NaN                            NaN               NaN             NaN
# Plant species                  ser               tyr             his
# Arabidopsis thaliana          2.41              0.19            0.13
# Chenopodium hybridum          1.54              0.62            0.35
# Plantago lanceolata           0.99              0.14            0.04
# Rumex acetosella                 7               0.9             0.3
# Trifolium repens              1.65              0.18            0.06
# Viola arvensis                2.16              0.23            0.07
# Rumex acetosa                 0.71              0.27            0.03
# Rumex obtusifolius            1.59              0.24             0.1
# Arctium minus                 3.09              0.61             0.3
# Chenopodium album             1.24              0.33            0.11
# Cirsium arvense               3.73              0.41            0.27
# Lamium purpureum              5.55              0.45            0.27
# Papaver dubium                 5.5              0.86            0.14
# Solanum nigrum                2.45              0.38            0.18
# Tropaeolum majus              0.82              0.14            0.07
# Vicia faba                     2.1              0.24            1.57
#
#                      Lamium purpureum Papaver dubium Solanum nigrum  \
# Metabolite
# sSUCROSE_b                    9.09091        28.5714             75
# L_ALPHA_ALANINE_c             5.72727        4.35714          2.325
# ARG_c                        0.636364       0.285714           0.35
# ASN_c                         2.54545        2.78571           1.35
# L_ASPARTATE_c                 1.90909           16.5           1.65
# GLT_c                         7.36364              8            3.1
# GLN_c                         55.9091        23.8571            8.2
# GLY_c                         4.90909       0.571429          0.675
# SER_c                         5.54545            5.5           2.45
# TYR_c                        0.454545       0.857143          0.375
# HIS_c                        0.272727       0.142857          0.175
# ILE_c                        0.454545       0.714286           0.55
# LEU_c                        0.636364       0.642857          0.575
# LYS_c                        0.545455       0.428571          0.475
# MET_c                        0.363636       0.214286           0.25
# PHE_c                        0.272727       0.214286            0.4
# THR_c                               2            3.5            0.9
# TRP_c                        0.545455       0.857143            0.5
# VAL_c                        0.818182              2          0.675
# NaN                               NaN            NaN            NaN
# NaN                               NaN            NaN            NaN
# NaN                               NaN            NaN            NaN
# NaN                               NaN            NaN            NaN
# NaN                               NaN            NaN            NaN
# Plant species                     ile            leu            lys
# Arabidopsis thaliana             0.38           0.38           0.56
# Chenopodium hybridum             0.62           0.65           0.77
# Plantago lanceolata              0.17           0.21           0.25
# Rumex acetosella                 0.55           0.75           0.65
# Trifolium repens                 0.13           0.18           0.21
# Viola arvensis                   0.21           0.26            0.3
# Rumex acetosa                    0.07           0.09           0.09
# Rumex obtusifolius                0.2           0.31           0.27
# Arctium minus                    0.39           0.57           0.61
# Chenopodium album                0.52           0.65           0.54
# Cirsium arvense                  0.45           0.55            0.5
# Lamium purpureum                 0.45           0.64           0.55
# Papaver dubium                   0.71           0.64           0.43
# Solanum nigrum                   0.55           0.58           0.48
# Tropaeolum majus                 0.13           0.24           0.21
# Vicia faba                       0.24           0.29           0.48
#
#                      Tropaeolum majus Vicia faba Unnamed: 17 Unnamed: 18  \
# Metabolite
# sSUCROSE_b                    89.6907     52.381         NaN         NaN
# L_ALPHA_ALANINE_c            0.773196    1.42857         NaN         NaN
# ARG_c                        0.103093   0.285714         NaN         NaN
# ASN_c                         4.29897    32.7143         NaN         NaN
# L_ASPARTATE_c                0.938144    1.61905         NaN         NaN
# GLT_c                         1.15464     1.7619         NaN         NaN
# GLN_c                        0.402062    3.19048         NaN         NaN
# GLY_c                        0.123711   0.380952         NaN         NaN
# SER_c                        0.819588    2.09524         NaN         NaN
# TYR_c                         0.14433   0.238095         NaN         NaN
# HIS_c                       0.0721649    1.57143         NaN         NaN
# ILE_c                        0.134021   0.238095         NaN         NaN
# LEU_c                        0.237113   0.285714         NaN         NaN
# LYS_c                        0.206186    0.47619         NaN         NaN
# MET_c                       0.0515464  0.0952381         NaN         NaN
# PHE_c                         0.14433   0.190476         NaN         NaN
# THR_c                        0.329897    0.47619         NaN         NaN
# TRP_c                         0.14433  0.0952381         NaN         NaN
# VAL_c                        0.195876    0.47619         NaN         NaN
# NaN                               NaN        NaN         NaN         NaN
# NaN                               NaN        NaN         NaN         NaN
# NaN                               NaN        NaN         NaN         NaN
# NaN                               NaN        NaN         NaN         NaN
# NaN                               NaN        NaN         NaN         NaN
# Plant species                     met        phe         thr         trp
# Arabidopsis thaliana             0.22       0.34        1.75        0.28
# Chenopodium hybridum             0.42       0.46        0.42        1.19
# Plantago lanceolata               0.1       0.13        0.44         0.1
# Rumex acetosella                 0.35        0.4         1.3         0.6
# Trifolium repens                 0.06       0.11        0.35        0.15
# Viola arvensis                   0.09       0.16         0.4        0.14
# Rumex acetosa                    0.04       0.09        0.28        0.39
# Rumex obtusifolius                0.2       0.27        0.86        0.27
# Arctium minus                    0.26       0.83        0.78        0.17
# Chenopodium album                0.26        0.2        0.72        0.61
# Cirsium arvense                  0.14       0.59           1        0.32
# Lamium purpureum                 0.36       0.27           2        0.55
# Papaver dubium                   0.21       0.21         3.5        0.86
# Solanum nigrum                   0.25        0.4         0.9         0.5
# Tropaeolum majus                 0.05       0.14        0.33        0.14
# Vicia faba                        0.1       0.19        0.48         0.1
#
#                      Unnamed: 19
# Metabolite
# sSUCROSE_b                   NaN
# L_ALPHA_ALANINE_c            NaN
# ARG_c                        NaN
# ASN_c                        NaN
# L_ASPARTATE_c                NaN
# GLT_c                        NaN
# GLN_c                        NaN
# GLY_c                        NaN
# SER_c                        NaN
# TYR_c                        NaN
# HIS_c                        NaN
# ILE_c                        NaN
# LEU_c                        NaN
# LYS_c                        NaN
# MET_c                        NaN
# PHE_c                        NaN
# THR_c                        NaN
# TRP_c                        NaN
# VAL_c                        NaN
# NaN                          NaN
# NaN                          NaN
# NaN                          NaN
# NaN                          NaN
# NaN                          NaN
# Plant species                val
# Arabidopsis thaliana        0.75
# Chenopodium hybridum        1.04
# Plantago lanceolata         0.43
# Rumex acetosella             1.1
# Trifolium repens            0.29
# Viola arvensis              0.47
# Rumex acetosa               0.16
# Rumex obtusifolius          0.47
# Arctium minus               0.87
# Chenopodium album           0.67
# Cirsium arvense                1
# Lamium purpureum            0.82
# Papaver dubium                 2
# Solanum nigrum              0.68
# Tropaeolum majus             0.2
# Vicia faba                  0.48
